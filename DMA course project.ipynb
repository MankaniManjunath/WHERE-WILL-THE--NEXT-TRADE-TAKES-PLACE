# %%
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_hdf("train_dc.h5",start=0,stop=11500)

# %%
data
# Out:
#       (0, ask)  (0, ask1)  (0, ask_size)  (0, ask_size1)  (0, bid)  (0, bid1)  \
# 0          4.5      562.5       0.002330        0.093197     -25.5     -545.5
# 1          2.5       14.5       0.001314        0.013139     -10.5     -406.5
# 2          5.0      210.0       0.010792        0.010792     -95.0     -285.0
# 3          0.5        1.5       0.006943        0.006943      -2.5       -3.5
# 4         15.0      442.0       0.035689        0.071378    -391.0     -397.0
# ...        ...        ...            ...             ...       ...        ...
# 1495      11.5      457.5       0.032196        0.032196      -9.5      -40.5
# 1496     386.5      387.5       0.028466        0.028466     -10.5     -406.5
# 1497       4.5      186.5       0.027609        0.027609      -6.5     -181.5
# 1498      22.0      759.0       0.041051        0.082102     -18.0     -738.0
# 1499       0.5        1.5       0.011298        0.005649      -1.5       -4.5
#
# ...

# %%
columns_updated = []
for i in data.columns:
    if isinstance(i,tuple) == True:
        columns_updated.append("{}_{}".format(str(i[0]),i[1]))
    else:
        columns_updated.append(i)
data.columns = columns_updated

# %%
data2 = pd.read_csv("train_labels.csv",nrows=11500)

# %%
data2.drop("ID",axis=1,inplace=True)

# %%
data2
# Out:
#        source_id
# 0              2
# 1              2
# 2              2
# 3              4
# 4              2
# ...          ...
# 11495          1
# 11496          1
# 11497          2
# 11498          1
# 11499          1
#
# [11500 rows x 1 columns]

# %%
df = data.interpolate()

# %%
df.isnull().sum()
# Out:
# 0_ask          0
# 0_ask1         0
# 0_ask_size     0
# 0_ask_size1    0
# 0_bid          0
#               ..
# 9_source_id    0
# 9_tod          0
# stock_id       0
# day_id         0
# ID             0
# Length: 97, dtype: int64

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
x = df
y = data2

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y.values,test_size=0.3)

# %%
model1 = SVC()
model2 = RandomForestClassifier(n_estimators=50)

# %%
#model1.fit(x_train,y_train)
model2.fit(x_train,y_train)
# Out:
# c:\python\python 3.7\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(n_estimators=50)

# %%
#print(model1.predict(x_test))
print(model2.predict(x_test))
# Out:
# [2 3 4 ... 4 4 4]

# %%
#print(model1.score(x_test,y_test))
print(model2.score(x_test,y_test))
# Out:
# 0.443768115942029

# %%
y_predicted = model.predict(x_test)

# %%
dd = pd.DataFrame(y_predicted)
dd.to_csv("D:/ouput.csv",index=False)

# %%
d = pd.read_csv("D:/ouput.csv",names=["Source_id"])
d
# Out:
#      Source_id
# 0            0
# 1            4
# 2            4
# 3            4
# 4            4
# ..         ...
# 446          4
# 447          4
# 448          4
# 449          4
# 450          4
#
# [451 rows x 1 columns]
